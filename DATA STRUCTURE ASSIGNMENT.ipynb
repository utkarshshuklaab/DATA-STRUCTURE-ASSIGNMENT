# %% [markdown]
# #DATA STRUCTURE ASSIGNMENT

# %%
#what are the data structures, and why they are important?
  ->'''Data structures are specialized formats used to organize, manage, and store data in a computer's memory or storage system. They provide an efficient way to arrange and manipulate data to perform operations like insertion, deletion, searching, sorting, and more. These structures are crucial in computer science and software engineering for several reasons:
  
  
  Efficient Data Organization: Data structures offer efficient means of organizing and managing data. They determine how data is stored in memory, making it easier to access, retrieve, and manipulate information.
  
  Optimized Operations: Different data structures excel in performing specific operations. For instance, arrays are excellent for quick access to elements by index, while linked lists are better for insertions and deletions. 
  
  Algorithms and Problem-Solving: Understanding data structures is crucial for designing algorithms. Efficient algorithms often rely on using the appropriate data structures to solve problems effectively.
  
  Memory Utilization: Data structures enable optimal memory utilization. By choosing the right structure, programmers can minimize memory wastage and enhance performance.
  
  Data Retrieval Speed: The choice of data structure significantly impacts the speed of data retrieval and manipulation. Some structures offer faster access to data, making operations more efficient.
  
  Scalability and Flexibility: Well-designed data structures allow for the scalability of applications. They can adapt to changes in data size or structure without compromising efficiency.
  
  Real-World Applications: Data structures are fundamental in the development of various applications, such as databases, operating systems, compilers, and more. For instance, databases use various data structures to organize and retrieve information efficiently.
  
  Understanding Efficiency Trade-offs: Different data structures have their own trade-offs. For instance, while arrays offer fast access to elements by index, they have a fixed size. Understanding these trade-offs is crucial for optimizing performance
  
  Software Design and Development: Choosing the right data structure is a critical aspect of software design. It impacts the overall architecture and functionality of the system.
  
  Learning Algorithms and Data Manipulation: Learning about data structures is a key part of understanding algorithms. It helps in improving problem-solving skills and developing efficient solutions.
  
  CONCLUSION:
  Overall, data structures form the backbone of computer science and software development. Their selection and implementation significantly impact the efficiency, speed, and scalability of software applications and systems. Therefore, a solid understanding of various data structures and their applications is crucial for any software developer or computer scientist.'''

# %%
#explain the difference between mutable and immutable data types with examples.

'''->Mutable Data Type – A mutable data type is one whose values can be changed.
Example: List, Dictionaries, and Set
Immutable Data Type – An immutable data type is one in which the values can’t be changed or altered.
Example: String and Tuples
'''

# %%
#mutable example
name = ['Vikram', 'Anshul', 'Amit', 'Suresh']
name.append('Kamal')
print(name)
# Out:
# ['Vikram', 'Anshul', 'Amit', 'Suresh', 'Kamal']

# %%
#immutable example
s = "hello"
t = s
s = s + " world"
print(s)          
print(t)
# Out:
# hello world
# hello

# %%
#what are the main difference between lists and tuples in python?

''' -> Lists are mutable(can be modified).	
2	Iteration over lists is time-consuming.	
3	Lists are better for performing operations, such as insertion and deletion.	
4	Lists consume more memory.
5	Lists have several built-inmethods.
6	Lists are more prone to unexpected changes and errors.	
  
   ->Tuples are immutable(cannot be modified).
2.  Iterations over tuple is faster
3.  Tuples are more suitable for accessing elements efficiently.
4.  Tuples consumes less memory
5.  Tuples have fewer built-in methods..
6n  Tuples, being immutable are less error prone.'''
  
#list example
a = [1, 2, 4, 4, 3, 3, 3, 6, 5]
a[3] = 77
print(a)
# Out:
# [1, 2, 4, 77, 3, 3, 3, 6, 5]

# %%
b = (0, 1, 2, 3)
b[0] = 4
print(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 b = (0, 1, 2, 3)
# ----> 2 b[0] = 4
#       3 print(b)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#describe how dictionaries store data

  '''->A Python dictionary is a data structure that stores the value in key: value pairs. Values in a dictionary can be of any data type and can be duplicated, whereas keys can’t be repeated and must be immutable.

Example: Here, The data is stored in key:value pairs in dictionaries, which makes it easier to find values.
'''

# %%
d = {1: 'Geeks', 2: 'For', 3: 'Geeks'}
print(d)
# Out:
# {1: 'Geeks', 2: 'For', 3: 'Geeks'}

# %%
'''How to Create a Dictionary
In Python, a dictionary can be created by placing a sequence of elements within curly {} braces, separated by a ‘comma’. 
'''

# %%
# create dictionary using { }
d1 = {1: 'Geeks', 2: 'For', 3: 'Geeks'}
print(d1)
d2 = dict(a = "Geeks", b = "for", c = "Geeks")
print(d2)
# Out:
# {1: 'Geeks', 2: 'For', 3: 'Geeks'}
# {'a': 'Geeks', 'b': 'for', 'c': 'Geeks'}

# %%
'''Accessing Dictionary Items
We can access a value from a dictionary by using the key within square brackets orget()method.
'''

# %%
d = { "name": "Alice", 1: "Python", (1, 2): [1,2,4] }
print(d["name"])
print(d.get("name"))
# Out:
# Alice
# Alice

# %%
'''Adding and Updating Dictionary Items
We can add new key-value pairs or update existing keys by using assignment.'''

# %%
d = {1: 'Geeks', 2: 'For', 3: 'Geeks'}
d["age"] = 22
d[1] = "Python dict"
print(d)
# Out:
# {1: 'Python dict', 2: 'For', 3: 'Geeks', 'age': 22}

# %%
'''Removing Dictionary Items
We can remove items from dictionary using the following methods:

del: Removes an item by key.
pop(): Removes an item by key and returns its value.
clear(): Empties the dictionary.
popitem(): Removes and returns the last key-value pair'''.

# %%
d = {1: 'Geeks', 2: 'For', 3: 'Geeks', 'age':22}
del d["age"]
print(d)
val = d.pop(1)
print(val)
key, val = d.popitem()
print(f"Key: {key}, Value: {val}")
d.clear()
print(d)
# Out:
# {1: 'Geeks', 2: 'For', 3: 'Geeks'}
# Geeks
# Key: 3, Value: Geeks
# {}

# %%
'''Iterating Through a Dictionary
We can iterate over keys [using keys() method] , values [using values() method] or both [using item() method] with a for loop.'''

# %%
d = {1: 'Geeks', 2: 'For', 'age':22}
for key in d:
    print(key)
for value in d.values():
    print(value)
for key, value in d.items():
    print(f"{key}: {value}")
# Out:
# 1
# 2
# age
# Geeks
# For
# 22
# 1: Geeks
# 2: For
# age: 22

# %%
'''Example of Nested Dictionary:'''

# %%
d = {1: 'Geeks', 2: 'For',
        3: {'A': 'Welcome', 'B': 'To', 'C': 'Geeks'}}
print(d)
# Out:
# {1: 'Geeks', 2: 'For', 3: {'A': 'Welcome', 'B': 'To', 'C': 'Geeks'}}

# %%
#why might you use a set instead of a list in python?

'''->when working with large dataset in python, the choice of data structure can significantly impact the performance of your code. Among the most commomnly used data structure are list and sets, both of which are designed to store collections of items.While lists are verstile and allow duplicate values, sets are unique in that they store only distinct elements and offer exceptional speech for certain operations, such as membership testing.
understanding the strengths and lead to better-optimized code.By leveraging the speed of sets for scenarios where duplicates aren't required, you can achieve faster execution times and lower computational costs.'''

# %%
#what is a string in python, and how is it different from list?
'''->String in Python
A string in Python is a sequence of characters enclosed within single quotes ('), double quotes ("), or triple quotes (''' or """). Strings are used to represent text data.

Example:'''

# %%
# Assigning string to a variable
a = 'This is a string'
print (a)
b = "This is a string"
print (b)
c= '''This is a string'''
print (c)
# Out:
# This is a string
# This is a string
# This is a string

# %%
'''Lists are one of the most powerful data structures in python. Lists are sequenced data types.  In Python, an empty list is created using list() function. They are just like the arrays declared in other language'''

# %%
tup = (1, "a", "string", 1+2)
print(tup)
print(tup[1])
# Out:
# (1, 'a', 'string', 3)
# a

# %%
#How do tuples ensure data integrity in python

'''
->Tuples are immutable to ensure that their constant throughout their lifecycle,gurananteeing data integrity and reliability.
This immutability allows tuples to be used as keys in dictionaries and elements in sets, as they can be hashed.
'''

# %%
#What is hash table, and how does it relate to dictionaries in python?

'''-> Hash table is a data structure that stores key value pairs and gives fast access to values based on their keys.
it converts, the key into index in an underlying array.
- In python, built-in(dict)=type is implemented using a hash table under the hood.
  .by using my_dict={'name': 'alice'}
  .hashes the key 'name'
  .uses that hash to find a location in memory
  .stores the value 'alice' there'''

# %%
#Can lists contain different data types in python?

'''-> Yes list contains different data types in python, it conyain various mix type data such as:-
   1. an integer(42)
   2.a string('hello')
   3.a float(3.42)
   4.a boolean(true)
   5.another list([1.2])
   6.a dictionary ({"key":"feature"})
   '''

# %%
#Explain why string are immutable in python?

'''->String in python are immutable, which means once a string is created, it cannot be changed.
    1. Efficiency and memory optimization 
    -python uses aa technique called string interning store commonly - used string only once in memory.
    2.Thread safety
    -since string can't be changed, they are safe to use across multiple threads without needing locks or other synchronization mechanisms
    3.hashability
    -immutable objects can be hashed.
    '''

# %%
#What advantages do dictionaries offer over lists for certain tasks?

'''->Dictionaries offer many offer such as:-
    1.fast lookups
    2.key- value pair structure.
    3.uniqueness of key
    4.Direct access
    5.more semantic code
    6.flexibilty with dynamic data'''

# %%
#How do sets handle duplicate values in python?

'''-> when you create a set, any duplicate elements are discarded, and only unique values are stored.
   for example:-
   my_set={1,2,3,4,4,4}
   print(my_set)
   {1,2,3,4}
   '''

# %%
#How does the "in" keyword work differently for lists and dictionaries?

'''-> IN WITH LISTS:-
when you use 'in' with list, it check value or elements in the lists.
example: list=[1,2,3,4]
         print(2 in list) True
         print(5 in list) False
     IN WITH DICTIONARIES:-
when you use 'in' with dictionaries, it checks the key value exists in dictionaries
example:  dict={"a":1:,"b;2"}
          print("a" in dict) True
          print(1 in dict) False (value are ignored)
          '''

# %%
#Can you modify the elements of tuple?explain why not?

'''-> you cannot change or modify the elements of tuple becuase tuple are immutable that means if it is created once it can't be change
but if tuple contains a mutable elements then inside that elements it can be changed like list'''

# %%
#What is nested dictionary, and give an example of its use case?

'''-> Nested dictionary is dictiinary where you can find some of the values are themselves dictionaries. tis is also useful in presentation.
     example of use case:-
     lets assume you are managing a student database ehereeach students has multiple attributes like name, grade, subjects, etc
     
student=
    'student_1':{
        'name':'angel]',
        'grade':{
        'math':70,
        'science':60
        }
        'student_2':{
             'name':'rahul',
             'grade':{
             'msth':80,
             'science':90
             }
        }
}'''

# %%
print(students['student_1']['grade']['math'])

# %%
#Describe the time complexity of accessing elements in a dictionary?

'''-> the time comlexity of accessing elements in a dictionaries mainly time = 0(1) on average
'''

# %%
#In what situation are lists preferred over dictionaries?
'''
1.when there is no key value pairs just need to store items in a specific order.
2.when you need to access items by index
3.when you allow to use duplicate value
4.list are easy to sort
5.when you only need to collect the value.
'''

# %%
#Why are dictionaries considered and how does that affect data retrieval?

'''-> dictionaries in python considered unordered because dictionaries use a hash table under the hood, where keys are hashed to determine
where their corresponding value are stored, the focus was on fast lookups, insertion, and deletion-not maintaining order.

how unoredered nature affected data retrieval:-
1.you couldn't rely on interaction order to be consistent.
2.sorting had to be explicity handled.'''

# %%
#Explain the difference between a list and a dictionary in terms data retrieval?

'''->difference between a list and a dictionary in term of dataas   are as follow :-
1. lists are indexed by position where as dictionary are indexed by keys
2. in lists data is retrived by using index number where as in dictionary data is retrived by using the key, not the positon.
'''

# %%
#Describe a  scenario where using a tuple would be preferable over a list.

'''-> Tuplses are immutable, which helps to protect the integrity of data but lists are mutable
suppose a person having his addhar no. that should not be changed right.
and if it is changeble so there is no protection of his data, why tuple is must to use this scenario.'''

# %%
#Write a code to create a string with your name and print it.
string="utkarsh"
print(string)
# Out:
# utkarsh

# %%
type(string)
# Out:
# str

# %%
#write a code to find the length of the string"hello world"
string="hello world"
len(string)
# Out:
# 11

# %%
#Write a code to slice the first 3 characters from the string "Python Programminh"
list=string[:3]
print(list)
# Out:
# hel

# %%
#Write a code to convert the string "hello" to uppercase.
string="hello"
string.upper()
# Out:
# 'HELLO'

# %%
#write a code to replace the world "apple" with "orange" in the string "I like apple"
string="i like apple"
string.replace("apple","orange")
# Out:
# 'i like orange'

# %%
#Write a code to create a list with numbers 1 to 5 and print it
list=[1,2,3,4,5]
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Write a code to append the number 10 to the list [1,2,3,4]
list=[1,2,3,4]
list.append(10)
print(list)
# Out:
# [1, 2, 3, 4, 10]

# %%
#Write a code to remove the number 3 from the list [1,2,3,4,5]
list=[1,2,3,4,5]
list.remove(3)
print(list)
# Out:
# [1, 2, 4, 5]

# %%
#Write a code to access the second element in the list['a','b','c','d']
list=['a','b','c','d']
list[1]
# Out:
# 'b'

# %%
#write a code to remove the list [10,20,30,40,50]
list=[10,20,30,40,50]
list[::-1]
# Out:
# [50, 40, 30, 20, 10]

# %%
#write a code to create a tuple with the elements 100,200,300,and printit
tuple=(100,200,300)
print(tuple)
# Out:
# (100, 200, 300)

# %%
#write a code to access the second -to- last elements of the ('red','green','blue','yello')
tuple=('red','green','blue','yelow')
print(tuple)
# Out:
# ('red', 'green', 'blue', 'yelow')

# %%
#write a code to find the minimum number in the tuple (10,20,5,,15)
tuple=(10,20,5,15)
min(tuple)
# Out:
# 5

# %%
#write a code to find the index of the element "cat" in the tuple ('dog','cat','rabbit')
tuple=('dog','cat','rabbit')
tuple.index('cat')
# Out:
# 1

# %%
#wite a code to create a tuple containing three different fruits and check if "kiwi" is in it
tuple=('mango','kiwi','apple')
if 'kiwi' in tuple:
    print('yes it is in tuple')
# Out:
# yes it is in tuple

# %%
#write a code to create a set with the elements 'a','b','c',and print it
set={'a','b','c',}
print(set)
# Out:
# {'a', 'c', 'b'}

# %%
#write a code to clear all elements from the set{1,2,3,4,5}
set={1,2,3,4,5}
set.clear()
print(set)
# Out:
# set()

# %%
#write a code to remove the elements 4 from the set {1,2,3,4}
set={1,2,3,4,}
set.remove(4)
print(set)
# Out:
# {1, 2, 3}

# %%
#write a code to find the union of two sets{1,2,3} and {3,4,5}
set1={1,2,3}
set2={3,4,5}
set.union(set1,set2)
# Out:
# {1, 2, 3, 4, 5}

# %%
#write a code to finf the ntersection of two sets{{1,2,3} and {{2,3,4}
set1={1,2,3}
set2={2,3,4}
set.intersection(set1,set2)
# Out:
# {2, 3}

# %%
#write a code to create a dictiionary with the keys 'name', 'age', 'city', and print it
dict={
    "name":"utkarsh",
    "age":23,
    "city":"pryagraj"
}
print(dict)
# Out:
# {'name': 'utkarsh', 'age': 23, 'city': 'pryagraj'}

# %%
#write a code to add a new value pair "'country" "usa" to the dictionary{'name':; 'john', 'age':25}
dict={'name':'john','age':25}
dict.update({"country":"usa"})
print(dict)
# Out:
# {'name': 'john', 'age': 25, 'country': 'usa'}

# %%
#write a code to access the value associated with the key "name" in the dictionary {'name':'alice',age30}
dict={'name':'alice','age':'30'}
dict_1=dict['name']
print(dict_1)
# Out:
# alice

# %%
#write a code to remove the key "age" from the dictionary {'name':'bob','age':22,'city':'new york'}
dict={'name':'bob','age':22,'city':'new york'}
del dict['age']
print(dict)
# Out:
# {'name': 'bob', 'city': 'new york'}

# %%
#write a code to check if key "city" exists in dictionary {'name':'alice','city':'Paris'}
dict={'name':'alice','city':'paris'}
if 'city'in dict:
    print('yes it is in dict')
else:
    pritn('no it is not present')
# Out:
# yes it is in dict

# %%
#write a code to create a list, a tuple, and a dictionary, and print them all
list=[1,2,3,4]
tuple={3,4,5}
dict={'name':'rahul','age':22}
print(list)
print(tuple)
print(dict)
# Out:
# [1, 2, 3, 4]
# {3, 4, 5}
# {'name': 'rahul', 'age': 22}

# %%
#write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result
list=[10,25,68,2,45,16]
list.sort()
print(list)
# Out:
# [2, 10, 16, 25, 45, 68]

# %%
#write a code to combine two dictinaries into one and print the reult
dict_1={'name':'rahul','city':'dhanbad'}
dict_2={'name':'joy','city':'new york'}
dict_1|=dict_2
print(dict_2)
# Out:
# {'name': 'joy', 'city': 'new york'}

# %%
#write a code to convert a list of string into a set
my_list=["1","2","3","4","5","5"]
my_set=set(my_list)
print(my_set)
# Out:
# {'5', '1', '4', '2', '3'}

# %%
type(my_set)
# Out:
# set
